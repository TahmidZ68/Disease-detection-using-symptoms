# %%
import pandas as pd
import pyttsx3
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier,_tree
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
import csv

training = pd.read_csv('Training.csv')
testing= pd.read_csv('Testing.csv')
cols= training.columns
cols= cols[:-1]
x = training[cols]
y = training['prognosis']
y1= y


reduced_data = training.groupby(training['prognosis']).max()
#%%
#mapping strings to numbers
le = preprocessing.LabelEncoder()
le.fit(y)
y = le.transform(y)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)
testx    = testing[cols]
testy    = testing['prognosis']  
testy    = le.transform(testy)

from sklearn.metrics import r2_score
model=SVC()
model.fit(x_train,y_train)
print("for svm: ")
print(model.score(x_test,y_test))

y_pred = model.predict(x_test)
score2 = r2_score(y_test, y_pred)*100
print("Accuracy rate with SVC", score2,"%")

import pickle
Model = pickle.dumps(model) 

import tkinter as tk
from tkinter import Tk, BOTH, Menu
from tkinter import messagebox
from tkinter import ttk
from tkinter.scrolledtext import ScrolledText
from tkinter import *

win = tk.Tk()
win.geometry("1000x1000")
win.title('Disease Predictions')

label = Label(win, text = "Predict your disease by clicks in Medihelp", bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 16")  
label.pack(padx=5, pady=15)


#img=PhotoImage(file='6600610_preview.png')
#Label(win,image=img,width=300,height=150).pack()

label = Label(win, text = "Tick your symptoms", bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 13")  
label.pack(padx=5, pady=15)

mb=  Menubutton ( win, text="Symptoms", relief=RAISED,font="BahnschriftLight 11", takefocus=0, bg="#100E30",
               fg="#F44336", activebackground="#100E38", activeforeground="#F44336",
              bd=0, highlightthickness=0, width=20, height=0 )
mb.pack()
mb.menu =  Menu ( mb, tearoff = 0 )
mb["menu"] =  mb.menu



for i in x.columns :
    val = tk.IntVar()
    mb.menu.add_checkbutton ( label=i,variable=val,onvalue=1,offvalue=0 )
    




def action():
    global db
    import pandas as pd
    df = pd.DataFrame(columns = x.columns)
    df.columns=df.columns.astype(str) 
    for i in df:
        df.loc[0]=val.get()
    db=df
        
    
def Output():
    output=model.predict(db)
    if output== 0:
            my_label = Label(win,text="Maybe you are affected with Drug reaction",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="An adverse drug reaction (ADR) is an injury caused by taking medication. ADRs may occur following a single dose or prolonged administration of a drug or result from the combination of two or more drugs.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 1:
            my_label = Label(win,text="Maybe you are affected with Malaria",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="An infectious disease caused by protozoan parasites from the Plasmodium family that can be transmitted by the bite of the Anopheles mosquito or by a contaminated needle or transfusion. Falciparum malaria is the most deadly type.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
    
    elif output== 2:
            my_label = Label(win,text="Maybe you are affected with Allergy",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="An allergy is an immune system response to a foreign substance that's not typically harmful to your body.They can include certain foods, pollen, or pet dander. Your immune system's job is to keep you healthy by fighting harmful pathogens.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 3:
            my_label = Label(win,text="Maybe you are affected with Hypothyroidism",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Hypothyroidism, also called underactive thyroid or low thyroid, is a disorder of the endocrine system in which the thyroid gland does not produce enough thyroid hormone.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
    
    elif output== 4:
            my_label = Label(win,text="Maybe you are affected with Psoriasis",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Psoriasis is a common skin disorder that forms thick, red, bumpy patches covered with silvery scales. They can pop up anywhere, but most appear on the scalp, elbows, knees, and lower back. Psoriasis can't be passed from person to person. It does sometimes happen in members of the same family.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)

    elif output== 5:
            my_label = Label(win,text="Maybe you are affected with GERD",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Gastroesophageal reflux disease, or GERD, is a digestive disorder that affects the lower esophageal sphincter (LES), the ring of muscle between the esophagus and stomach. Many people, including pregnant women, suffer from heartburn or acid indigestion caused by GERD.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)       

    elif output== 6:
            my_label = Label(win,text="Maybe you are affected with Chronic cholestasis",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Chronic cholestatic diseases, whether occurring in infancy, childhood or adulthood, are characterized by defective bile acid transport from the liver to the intestine, which is caused by primary damage to the biliary epithelium in most cases",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)       
            
            
    elif output== 7:
            my_label = Label(win,text="Maybe you are affected with Hepatitis A",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Hepatitis A is a highly contagious liver infection caused by the hepatitis A virus. The virus is one of several types of hepatitis viruses that cause inflammation and affect your liver's ability to function.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)        
            
    elif output== 8:
            my_label = Label(win,text="Maybe you are affected with Osteoarthristis",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Osteoarthritis is the most common form of arthritis, affecting millions of people worldwide. It occurs when the protective cartilage that cushions the ends of your bones wears down over time.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 9:
            my_label = Label(win,text="Maybe you are affected with (vertigo) Paroymsal  Positional Vertigo",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Benign paroxysmal positional vertigo (BPPV) is one of the most common causes of vertigo â€” the sudden sensation that you're spinning or that the inside of your head is spinning. Benign paroxysmal positional vertigo causes brief episodes of mild to intense dizziness.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 10:
            my_label = Label(win,text="Maybe you are affected with Hypoglycemia",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text=" Hypoglycemia is a condition in which your blood sugar (glucose) level is lower than normal. Glucose is your body's main energy source. Hypoglycemia is often related to diabetes treatment. But other drugs and a variety of conditions â€” many rare â€” can cause low blood sugar in people who don't have diabetes.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 11:
            my_label = Label(win,text="Maybe you are affected with Acne",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Acne vulgaris is the formation of comedones, papules, pustules, nodules, and/or cysts as a result of obstruction and inflammation of pilosebaceous units (hair follicles and their accompanying sebaceous gland). Acne develops on the face and upper trunk. It most often affects adolescents.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 12:
            my_label = Label(win,text="Maybe you are affected with Diabetes",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Diabetes is a disease that occurs when your blood glucose, also called blood sugar, is too high. Blood glucose is your main source of energy and comes from the food you eat. Insulin, a hormone made by the pancreas, helps glucose from food get into your cells to be used for energy.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 13:
            my_label = Label(win,text="Maybe you are affected with Impetigo",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Impetigo (im-puh-TIE-go) is a common and highly contagious skin infection that mainly affects infants and children. Impetigo usually appears as red sores on the face, especially around a child's nose and mouth, and on hands and feet. The sores burst and develop honey-colored crusts.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 14:
            my_label = Label(win,text="Maybe you are affected with Hypertension",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Hypertension (HTN or HT), also known as high blood pressure (HBP), is a long-term medical condition in which the blood pressure in the arteries is persistently elevated. High blood pressure typically does not cause symptoms.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 15:
            my_label = Label(win,text="Maybe you are affected with Peptic ulcer diseae",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Peptic ulcer disease (PUD) is a break in the inner lining of the stomach, the first part of the small intestine, or sometimes the lower esophagus. An ulcer in the stomach is called a gastric ulcer, while one in the first part of the intestines is a duodenal ulcer.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 16:
            my_label = Label(win,text="Maybe you are affected with Dimorphic hemorrhoids(piles)",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Hemorrhoids, also spelled haemorrhoids, are vascular structures in the anal canal. In their ... Other names, Haemorrhoids, piles, hemorrhoidal disease .",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 17:
            my_label = Label(win,text="Maybe you are affected with Common Cold",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="The common cold is a viral infection of your nose and throat (upper respiratory tract). It's usually harmless, although it might not feel that way. Many types of viruses can cause a common cold.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 18:
            my_label = Label(win,text="Maybe you are affected with Chicken pox",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Chickenpox is a highly contagious disease caused by the varicella-zoster virus (VZV). It can cause an itchy, blister-like rash. The rash first appears on the chest, back, and face, and then spreads over the entire body, causing between 250 and 500 itchy blisters.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 19:
            my_label = Label(win,text="Maybe you are affected with Cervical spondylosis",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Cervical spondylosis is a general term for age-related wear and tear affecting the spinal disks in your neck. As the disks dehydrate and shrink, signs of osteoarthritis develop, including bony projections along the edges of bones (bone spurs).",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 20:
            my_label = Label(win,text="Maybe you are affected with Hyperthyroidism",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Hyperthyroidism (overactive thyroid) occurs when your thyroid gland produces too much of the hormone thyroxine. Hyperthyroidism can accelerate your body's metabolism, causing unintentional weight loss and a rapid or irregular heartbeat.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 21:
            my_label = Label(win,text="Maybe you are affected with Urinary tract infection",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Urinary tract infection: An infection of the kidney, ureter, bladder, or urethra. Abbreviated UTI. Not everyone with a UTI has symptoms, but common symptoms include a frequent urge to urinate and pain or burning when urinating.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 22:
            my_label = Label(win,text="Maybe you are affected with Varicose veins",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="A vein that has enlarged and twisted, often appearing as a bulging, blue blood vessel that is clearly visible through the skin. Varicose veins are most common in older adults, particularly women, and occur especially on the legs.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 23:
            my_label = Label(win,text="Maybe you are affected with AIDS",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Acquired immunodeficiency syndrome (AIDS) is a chronic, potentially life-threatening condition caused by the human immunodeficiency virus (HIV). By damaging your immune system, HIV interferes with your body's ability to fight infection and disease.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 24:
            my_label = Label(win,text="Maybe you are affected with Paralysis (brain hemorrhage)",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Intracerebral hemorrhage (ICH) is when blood suddenly bursts into brain tissue, causing damage to your brain. Symptoms usually appear suddenly during ICH. They include headache, weakness, confusion, and paralysis, particularly on one side of your body.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 25:
            my_label = Label(win,text="Maybe you are affected with Typhoid",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="An acute illness characterized by fever caused by infection with the bacterium Salmonella typhi. Typhoid fever has an insidious onset, with fever, headache, constipation, malaise, chills, and muscle pain. Diarrhea is uncommon, and vomiting is not usually severe.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 26:
            my_label = Label(win,text="Maybe you are affected with Hepatitis B",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Hepatitis B is an infection of your liver. It can cause scarring of the organ, liver failure, and cancer. It can be fatal if it isn't treated. It's spread when people come in contact with the blood, open sores, or body fluids of someone who has the hepatitis B virus.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 27:
            my_label = Label(win,text="Maybe you are affected with Fungal infection",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="In humans, fungal infections occur when an invading fungus takes over an area of the body and is too much for the immune system to handle. Fungi can live in the air, soil, water, and plants. There are also some fungi that live naturally in the human body. Like many microbes, there are helpful fungi and harmful fungi.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 28:
            my_label = Label(win,text="Maybe you are affected with Hepatitis C",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Inflammation of the liver due to the hepatitis C virus (HCV), which is usually spread via blood transfusion (rare), hemodialysis, and needle sticks. The damage hepatitis C does to the liver can lead to cirrhosis and its complications as well as cancer.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 29:
            my_label = Label(win,text="Maybe you are affected with Migraine",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="A migraine can cause severe throbbing pain or a pulsing sensation, usually on one side of the head. It's often accompanied by nausea, vomiting, and extreme sensitivity to light and sound. Migraine attacks can last for hours to days, and the pain can be so severe that it interferes with your daily activities.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 30:
            my_label = Label(win,text="Maybe you are affected with Bronchial Asthma",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Bronchial asthma is a medical condition which causes the airway path of the lungs to swell and narrow. Due to this swelling, the air path produces excess mucus making it hard to breathe, which results in coughing, short breath, and wheezing. The disease is chronic and interferes with daily working.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 31:
            my_label = Label(win,text="Maybe you are affected with Alcoholic hepatitis",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Alcoholic hepatitis is a diseased, inflammatory condition of the liver caused by heavy alcohol consumption over an extended period of time. It's also aggravated by binge drinking and ongoing alcohol use. If you develop this condition, you must stop drinking alcohol",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 32:
            my_label = Label(win,text="Maybe you are affected with Jaundice",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Yellow staining of the skin and sclerae (the whites of the eyes) by abnormally high blood levels of the bile pigment bilirubin. The yellowing extends to other tissues and body fluids. Jaundice was once called the morbus regius (the regal disease) in the belief that only the touch of a king could cure it",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 33:
            my_label = Label(win,text="Maybe you are affected with Hepatitis E",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="A rare form of liver inflammation caused by infection with the hepatitis E virus (HEV). It is transmitted via food or drink handled by an infected person or through infected water supplies in areas where fecal matter may get into the water. Hepatitis E does not cause chronic liver disease.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 34:
            my_label = Label(win,text="Maybe you are affected with Dengue",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="an acute infectious disease caused by a flavivirus (species Dengue virus of the genus Flavivirus), transmitted by aedes mosquitoes, and characterized by headache, severe joint pain, and a rash. â€” called also breakbone fever, dengue fever.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 35:
            my_label = Label(win,text="Maybe you are affected with Hepatitis D",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Hepatitis D, also known as the hepatitis delta virus, is an infection that causes the liver to become inflamed. This swelling can impair liver function and cause long-term liver problems, including liver scarring and cancer. The condition is caused by the hepatitis D virus (HDV).",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 36:
            my_label = Label(win,text="Maybe you are affected with Heart attack",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="The death of heart muscle due to the loss of blood supply. The loss of blood supply is usually caused by a complete blockage of a coronary artery, one of the arteries that supplies blood to the heart muscle.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 37:
            my_label = Label(win,text="Maybe you are affected with Pneumonia",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Pneumonia is an infection in one or both lungs. Bacteria, viruses, and fungi cause it. The infection causes inflammation in the air sacs in your lungs, which are called alveoli. The alveoli fill with fluid or pus, making it difficult to breathe.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 38:
            my_label = Label(win,text="Maybe you are affected with Arthritis",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Arthritis is the swelling and tenderness of one or more of your joints. The main symptoms of arthritis are joint pain and stiffness, which typically worsen with age. The most common types of arthritis are osteoarthritis and rheumatoid arthritis.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 39:
            my_label = Label(win,text="Maybe you are affected with Gastroenteritis",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Gastroenteritis is an inflammation of the digestive tract, particularly the stomach, and large and small intestines. Viral and bacterial gastroenteritis are intestinal infections associated with symptoms of diarrhea , abdominal cramps, nausea , and vomiting .",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
    elif output== 40:
            my_label = Label(win,text="Maybe you are affected with Tuberculosis",bg = "#100E30", bd = 10, fg = "white", font="BahnschriftLight 10").pack(pady=5)
            my_label1 = Label(win,text="Tuberculosis (TB) is an infectious disease usually caused by Mycobacterium tuberculosis (MTB) bacteria. Tuberculosis generally affects the lungs, but can also affect other parts of the body. Most infections show no symptoms, in which case it is known as latent tuberculosis.",bg = "#100E30",wraplength=500, justify="center", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=5)
            my_label2 = Label(win,text="You should: \n 1) Exercise\n 2)Use hot and cold therapy\n 3)Try acupuncture\n 4)Massage",bg = "#100E30",wraplength=500, justify="left", bd = 10, fg = "white", font="BahnschriftLight 9").pack(pady=2)
            
           
            
            
            
            
            

Action_button=Button(win,text="Submit",command=action,bd = 10, fg = "white",bg = "#b7d2f7")
Predict_button=Button(win,text="Predict",command=Output,bd = 10, fg = "white",bg = "#b7d2f7")
Action_button.pack(pady=15)
Predict_button.pack(pady=5)

win.mainloop()
# Out:
# for svm:
# 1.0
# Accuracy rate with SVC 100.0 %
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\PC\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_14272\3420502257.py", line 91, in action
#     for i in df and var:
#   File "C:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py", line 1535, in __nonzero__
#     raise ValueError(
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\PC\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_14272\3420502257.py", line 97, in Output
#     output=model.predict(db)
# ...
